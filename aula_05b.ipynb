# %% [markdown]
# # PLOTAGEM

# %%
import pandas as pd
import numpy as np

# mais usado
import matplotlib.pyplot as plt

# mais robustos
import matplotlib.gridspec as gridspec

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,4))

ax1.plot(
    [1,2,3,4,5,6,7],
    [1,2,1,1,4,5,7]
)
ax2.bar(
    [1,2,3,4,5,6,7],
    [1,2,1,1,4,5,7]
)

plt.show()

# %%
x = np.linspace(0, 4*np.pi, 1000)
y = np.sin(x)

plot = {
    "x":x,
    "y":y
}
df_plot = pd.DataFrame(plot)
df_plot.head()
# Out:
#           x         y
# 0  0.000000  0.000000
# 1  0.012579  0.012579
# 2  0.025158  0.025155
# 3  0.037737  0.037728
# 4  0.050316  0.050295

# %%
fig, ax = plt.subplots()

ax.plot(df_plot.x, df_plot.y)

plt.show()

# %%
x1 = np.random.uniform(0, 1, 100)
y1 = np.random.uniform(0, 1, 100)

plot = {
    "x1":x1,
    "y1":y1
}
df_plot1 = pd.DataFrame(plot)
df_plot1.head()
# Out:
#          x1        y1
# 0  0.808842  0.812148
# 1  0.187209  0.096379
# 2  0.920327  0.481853
# 3  0.443113  0.063692
# 4  0.612864  0.556328

# %%
fig, ax = plt.subplots()

ax.scatter(df_plot1.x1, df_plot1.y1)

plt.show()

# %%
x3 = np.arange(10)
y3 = np.random.uniform(1, 10, 10)

plot = {
    "x3":x3,
    "y3":y3
}
df_plot3 = pd.DataFrame(plot)
df_plot3.head()
# Out:
#    x3        y3
# 0   0  9.412234
# 1   1  4.217063
# 2   2  7.928669
# 3   3  5.838003
# 4   4  3.262783

# %%
fig, ax = plt.subplots()

ax.bar(df_plot3.x3, df_plot3.y3)

plt.show()

# %%
xy = np.random.uniform(0, 1, (8,8))

plot = {
    "x4":xy[0],
    "y4":xy[1]
}
df_plot4 = pd.DataFrame(plot)
df_plot4.head()
# Out:
#          x4        y4
# 0  0.402800  0.197188
# 1  0.749642  0.347672
# 2  0.554644  0.883120
# 3  0.811302  0.726752
# 4  0.033814  0.889195

# %%
fig, ax = plt.subplots()

ax.imshow(df_plot4, vmin=0, vmax=8)

plt.show()

# %%
xy = np.random.uniform(0, 1, (8,8))

plot = {
    "x5":xy[0],
    "y5":xy[1]
}
df_plot5 = pd.DataFrame(plot)
df_plot5.head()
# Out:
#          x5        y5
# 0  0.805525  0.582015
# 1  0.520014  0.383146
# 2  0.445815  0.411599
# 3  0.203260  0.598131
# 4  0.454400  0.581104

# %%
fig, ax = plt.subplots()

ax.contour(df_plot4, vmin=0, vmax=8)

plt.show()

# %%
x = np.random.uniform(0, 1, 4)

s_plot1 = pd.Series(x)
s_plot1.head()
# Out:
# 0    0.812354
# 1    0.558464
# 2    0.185558
# 3    0.960932
# dtype: float64

# %%
fig, ax = plt.subplots()

labels = ["a", "b", "c", "d"]
explode = (0.1, 0.1, 0.1, 0.1)

ax.pie(
    s_plot1,
    explode=explode,
    labels=labels,
    autopct="%1.1f%%",
    shadow=True,
    startangle=90
)

plt.show()
