# %% [markdown]
# # RELATORIO VII

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("datasets/Advertising.csv", index_col="Unnamed: 0")

# %%
df.head(2)
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.columns = ['TV', 'Radio', 'Jornal', 'Vendas']

# %%
df.head(2)
# Out:
#       TV  Radio  Jornal  Vendas
# 1  230.1   37.8    69.2    22.1
# 2   44.5   39.3    45.1    10.4

# %%
df.isna().sum()
# Out:
# TV        0
# Radio     0
# Jornal    0
# Vendas    0
# dtype: int64

# %%
df.plot.box(vert=False, figsize=(15, 4))
# Out:
# <Axes: >

# %%
df.Jornal[df.Jornal < 100].plot.box(vert=False, figsize=(15, 4))  # 17, 102
# Out:
# <Axes: >

# %%
df.Jornal[df.Jornal > 100].value_counts() # 17, 102
# Out:
# Series([], Name: count, dtype: int64)

# %%
# excluindo as linhas com a condicao
# df = df.drop(df[df.Jornal > 100].index)

# calocar valores padrao
df.Jornal = df.Jornal.clip(lower=0, upper=90)

# %%
df.plot.box(vert=False, figsize=(15,4))
# Out:
# <Axes: >

# %%
# Correlacao entre colunas
df_corr = df.corr()
df_corr
# Out:
#               TV     Radio    Jornal    Vendas
# TV      1.000000  0.054809  0.058918  0.782224
# Radio   0.054809  1.000000  0.356194  0.576223
# Jornal  0.058918  0.356194  1.000000  0.231221
# Vendas  0.782224  0.576223  0.231221  1.000000

# %%
df.plot.scatter("Jornal", "Vendas") #TV, Radio
# Out:
# <Axes: xlabel='Jornal', ylabel='Vendas'>

# %%
# COVARIANCA 
df_cov = df.cov()
df_cov
# Out:
#                  TV       Radio      Jornal      Vendas
# TV      7370.949893   69.862492  107.295448  350.390195
# Radio     69.862492  220.427743  112.174585   44.635688
# Jornal   107.295448  112.174585  449.935306   25.589459
# Vendas   350.390195   44.635688   25.589459   27.221853

# %%
df_cov.plot.bar(ylim=[0, 700]) #TV, Radio
# Out:
# <Axes: >

# %% [markdown]
# # Analise descritivo (O que aconteceu)

# %%
df.describe()
# Out:
#                TV       Radio      Jornal      Vendas
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.379500   14.022500
# std     85.854236   14.846809   21.211679    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000   90.000000   27.000000

# %%
# Soma dos valores gastos
print(f"Gasto com TV: {df.TV.sum()}")
print(f"Gasto com Radio: {df.Radio.sum()}")
print(f"Gasto com Jornal: {df.Jornal.sum()}")
# Out:
# Gasto com TV: 29408.5
# Gasto com Radio: 4652.800000000001
# Gasto com Jornal: 6075.9

# %%
# Mediana
print(f"Valor central do gasto com TV: {df.TV.median()}")
print(f"Valor central do gasto com Radio: {df.Radio.median()}")
print(f"Valor central do gasto com Jornal: {df.Jornal.median()}")
# Out:
# Valor central do gasto com TV: 149.75
# Valor central do gasto com Radio: 22.9
# Valor central do gasto com Jornal: 25.75

# %%
# Media
print(f"Media do gasto com TV: {df.TV.mean()}")
print(f"Media do gasto com Radio: {df.Radio.mean()}")
print(f"Media do gasto com Jornal: {df.Jornal.mean()}")
# Out:
# Media do gasto com TV: 147.0425
# Media do gasto com Radio: 23.264000000000006
# Media do gasto com Jornal: 30.379499999999997

# %%
# varianca
print(f"Varianca do Gasto com TV: {df.TV.var()}")
print(f"Varianca do Gasto com Radio: {df.Radio.var()}")
print(f"Varianca do Gasto com Jornal: {df.Jornal.var()}")
# Out:
# Varianca do Gasto com TV: 7370.949893216087
# Varianca do Gasto com Radio: 220.4277427135678
# Varianca do Gasto com Jornal: 449.9353062814071

# %%
# Desvio Padrao
print(f"Desvio padrao do Gasto com TV: {df.TV.std()}")
print(f"Desvio padrao do Gasto com Radio: {df.Radio.std()}")
print(f"Desvio padrao do Gasto com Jornal: {df.Jornal.std()}")
# Out:
# Desvio padrao do Gasto com TV: 85.8542363149081
# Desvio padrao do Gasto com Radio: 14.846809176168723
# Desvio padrao do Gasto com Jornal: 21.21167853521751

# %%
# Moda
print(f"Valor que mais repete do Gasto com TV: {list(df.TV.mode())}")
print(f"Valor que mais repete do Gasto com Radio: {list(df.Radio.mode())}")
print(f"Valor que mais repete do Gasto com Jornal: {list(df.Jornal.mode())}")
# Out:
# Valor que mais repete do Gasto com TV: [17.2, 76.4, 109.8, 177.0, 184.9, 197.6, 199.8, 222.4, 237.4, 240.1]
# Valor que mais repete do Gasto com Radio: [4.1, 5.7]
# Valor que mais repete do Gasto com Jornal: [8.7, 9.3, 25.6]

# %%
df_vendas =  pd.qcut(
    df.Vendas, q=4, 
    labels=[
        "Vendas ate 10.37", 
        "Vendas de 10.38 a 12.9",
        "Vendas de 13 a 17.4",
        "Vendas de acima de 17.4"
    ]
)

# %%
df_vendas.head(2)
# Out:
# 1    Vendas de acima de 17.4
# 2     Vendas de 10.38 a 12.9
# Name: Vendas, dtype: category
# Categories (4, object): ['Vendas ate 10.37' < 'Vendas de 10.38 a 12.9' < 'Vendas de 13 a 17.4' < 'Vendas de acima de 17.4']

# %%
plt.figure(figsize=(15, 6))

sns.boxplot(
    data=df, 
    x=df.Radio, 
    y=df_vendas, 
    orient="h", 
    hue=df_vendas
)

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(15, 4))

sns.scatterplot(
    data=df,
    x="Radio",
    y="Vendas",
    hue=df_vendas,
    size=df_vendas,
    sizes=(20, 200),
    legend="full"
)

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(15,4))
plt.scatter(
    df.TV, 
    df.Vendas
)
# plt.grid(True)
plt.show()

# %% [markdown]
# # Diagnostica (Porque aconteceu?)

# %%
fig, ax = plt.subplots(2, 4, figsize=(15, 9))

sns.histplot(ax=ax[0,0], data=df, x="TV", bins=20, kde=True)
sns.histplot(ax=ax[0,1], data=df, x="Radio", bins=20, kde=True)
sns.histplot(ax=ax[0,2], data=df, x="Jornal", bins=20, kde=True)
sns.histplot(ax=ax[0,3], data=df, x="Vendas", bins=20, kde=True)

sns.histplot(ax=ax[1,0], data=df, x="TV", bins=20, kde=True, hue=df_vendas)
sns.histplot(ax=ax[1,1], data=df, x="Radio", bins=20, kde=True, hue=df_vendas)
sns.histplot(ax=ax[1,2], data=df, x="Jornal", bins=20, kde=True, hue=df_vendas)
sns.histplot(ax=ax[1,3], data=df, x="Vendas", bins=20, kde=True, hue=df_vendas)



plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,4))

sns.kdeplot(
    ax=ax[0],
    data=df,
    x="Vendas",
    y="TV", 
    fill=True,
    thresh=0,
    levels=100, 
    cmap="mako"
)

sns.kdeplot(ax=ax[1], data=df, x="Vendas", y="Radio", fill=True, thresh=0, levels=100, cmap="mako")
sns.kdeplot(ax=ax[2], data=df, x="Vendas", y="Jornal", fill=True, thresh=0, levels=100, cmap="mako")

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(
    df, 
    x_vars=["TV", "Radio", "Jornal"], 
    y_vars="Vendas",
    height=3,
    aspect=2,
    kind="reg"
)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# # Descritivo

# %%
from scipy import stats

# %%
# Tempo de veiculo
x = [5, 7, 8, 7, 17, 2, 3, 9, 4]

# velocidade
y = [99, 86, 88, 89, 110, 103, 111, 94, 99]

# %%
coef, intercept, r, p, std_err = stats.linregress(x, y)

def linha_reg(item):
    return coef*item + intercept

modelo = list(map(linha_reg, x))

# %%
plt.figure(figsize=(15,7))

plt.scatter(x, y)
plt.plot(x, modelo)

plt.show()

# %%
# Tempo de veiculo
x = [5, 7, 8, 7, 17, 2, 3, 9, 4]

# velocidade
y = [99, 86, 88, 89, 110, 103, 111, 94, 99]

# %%
def linha_reg(item):
    return coef*item + intercept - std_err - r

# %%
x_test = 4

y_test = linha_reg(x_test)

# %%
print(f"Velocidade prevista: {round(y_test, 2)}")
# Out:
# Velocidade prevista: 96.47

# %%
(86 + 89)/2
# Out:
# 87.5
